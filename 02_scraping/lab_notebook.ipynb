# %% [markdown]
# # Web Scraping
#
# Last time, we looked at REST API's as a source of data. You can get lots of very high quality data this way.
#
# Some data is available online, but not through an API. When this is the case, some times you can simply copy and paste the data into a .csv file and go on with your life. But if there are many records to parse and combine into a dataset, that might be impossible. Can we automate the collection of data from online sources?
#
# This is called web scraping. Broadly speaking: Web scraping is legal, but what you plan to do with the results of your scraping might not be. In general, most sites do not want you to scrape them at this point, but there is not really a way to stop you if you are sufficiently motivated. Be careful to use server resources respectfully (not too many requests per unit time), think seriously about privacy concerns, and be careful who you share your work with.

# %% [markdown]
# We'll be scraping data about used cars in Charlottesville from Craigslist. This will give us a chance to put those wrangling, EDA, and visualization skills to work.
#
# We'll use the `requests` package, as we did with API's, but will be getting the kinds of web pages you see everyday. Again, we'll use a header with a user-agent that masks our true identity so that we're not rejected by the server. This particular url points to the car listings for Craigslist in Charlottesville.

# %% [markdown]
# ## 1. Pick something else on Craigslist: Musical instruments, roommates, antiques, etc. Look at the search page and its source code. Record which fields/data you would like to gather, and what kinds of EDA you'd do with it. I look at used cars below.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'}
url = 'https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0'
raw = requests.get(url,headers=header) # Get page

# %% [markdown]
# Now that we have that particular page available locally, we want to **parse** it and get results from it. To do that, we can use a package called `beautifulSoup` or `bs4`.
#
# What does `beautifulSoup` do for us? Let's go to the web page of interest. You probably see something like this:
#
# ![Listings](craigslist.png "Craigslist")
#
# But if you "view page source" -- which is CTRL+U -- in Chrome, you see what the computer sees:
#
# ![Listings](craigslist_source.png "Craigslist")
#
# Since your web browser needs lots of instructions about how to render the text, pictures, and other content on your web page, there are a lot of clues about where the data live and how to extricate them from a page. These clues are called **tags**. If you wander the source for the search page on cars, you see a particular `class = "cl-static-search-result"` term appear attached to each listing:
#
# ![Listings](listing.png "Craigslist")
#
# This structure can be exploited to search the page for information. This kind of detective work -- looking at the page source, finding the interesting tages, and then searching the page with `beautifulSoup` -- is the basic job of web scraping.

# %% [markdown]
# ## 2. Get your search results of interest and extract data from them, using code similar to what's below.

# %% [markdown]
# The following code chunk takes the raw content from `requests` and turns it into a beautifulSoup object, which can search the page and return results for us:

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings

# %% [markdown]
# Why is the argument `class_` and not just `class`? The word `class` is a reserved keyword for Python, and cannot be used by anyone else, similar to `True` and `False`. But since we want the `class = "cl-static-search-result"` terms, we need to use the `class_` argument to the `.find_all` method.
#
# The `.find_all` function dredges the entire page and finds all the instances of `class = "cl-static-search-result"`, resulting in a list of entries. We can then parse the entries.
#
# For each listing, we'll use the `.find` method to search within the listing record for specific information. To get the information we want, we can then use `.get_text()`.
#
# In the code below, two more things happen.
#
# First, I would like to get the brand of the car from the post title, if possible. To do this, I split the title into words using `title.split()`, and then I use a list comprehension to look over every word in the title and check whether it appears in the `brands` list.
#
# Second, I would like to get the year the car was built, so I can determine the vehicle's age. To do this, I use a thing called **regular expressions** that provides a language for expressing patterns. Do I remember how to do this off the top of my head? No, I read a few pages in a book and looked on StackOverflow for answers. Roughly, in order to express the idea "any year starting with 20xx," you can write `20[0-9][0-9]`, and for "any year starting with 19xx," you can write `19[0-9][0-9]`. The `[0-9]`'s act as wildcards for any digit. This allows me to use the `re` package to find any instances of year-like numbers in the title text, using `re.search(r'20[0-9][0-9]|19[0-9][0-9]', title )`.
#
# This is all nested in a for-loop over the listings, and the data is appended to a list.

# %%
import re # Regular expressions

brands = ['honda', 'dodge','toyota','ford','tesla','gmc','jeep','bmw','mitsubishi','mazda',
          'volvo','audi','volkswagen','chevy','chevrolet','acura','kia','subaru','lexus',
          'cadillac','buick','porsche','infiniti']

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in brands] # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'brand':brand})

# %%
print(data)
# Out:
# [{'title': '2016 nissan altima sl', 'price': '$4,800', 'year': '2016', 'link': 'https://charlottesville.craigslist.org/cto/d/palmyra-2016-nissan-altima-sl/7788212655.html', 'brand': 'missing'}, {'title': 'buick', 'price': '$4,000', 'year': nan, 'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-buick/7788145297.html', 'brand': 'buick'}, {'title': '2006 buick lacrosse cx', 'price': '$2,600', 'year': '2006', 'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2006-buick-lacrosse-cx/7788091829.html', 'brand': 'buick'}, {'title': '2005 ford f-150 2wd- not running', 'price': '$1,000', 'year': '2005', 'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2005-ford-150-2wd-not/7788041184.html', 'brand': 'ford'}, {'title': '2008 subaru impreza', 'price': '$2,000', 'year': '2008', 'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2008-subaru-impreza/7787924583.html', 'brand': 'subaru'}, {'title': '2018 tesla model 3 mid range or 2018 tesla model s75d awd', 'price': '$16,900', 'year': '2018', 'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2018-tesla-model-mid-range-or/7787917504.html', 'brand': 'tesla'}, {'title': '2010 lexus is250c convertible', 'price': '$14,950', 'year': '2010', 'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2010-lexus-is250c/7787904942.html', 'brand': 'lexus'}, {'title': '2010 chevy malibu 4-door (pending)', 'price': '$800', 'year': '2010', 'link': 'https://charlottesville.craigslist.org/cto/d/palmyra-2010-chevy-malibu-door-pending/7787579204.html', 'brand': 'chevy'}, {'title': 'bmw x5', 'price': '$8,500', 'year': nan, 'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-bmw-x5/7787579073.html', 'brand': 'bmw'}, {'title': 'bmw z3', 'price': '$5,900', 'year': nan, 'link': 'https://charlottesville.craigslist.org/cto/d/staunton-bmw-z3/7787567192.html', 'brand': 'bmw'}, {'title': '1998 toyota camery', 'price': '$1,500', 'year': '1998', 'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1998-toyota-camery/7787566957.html', 'brand': 'toyota'}, {'title': '2010 e550 mercedes sedan', 'price': '$7,650', 'year': '2010', 'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2010-e550-mercedes-sedan/7787286459.html', 'brand': 'missing'}, {'title': 'dodge 4x4', 'price': '$3,700', 'year': nan, 'link': 'https://charlottesville.craigslist.org/cto/d/banco-dodge-4x4/7787130319.html', 'brand': 'dodge'}, {'title': 'affordable car works well', 'price': '$1,950', 'year': nan, 'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-affordable-car-works-well/7786935849.html', 'brand': 'missing'}, {'title': '1998 chevy pickup', 'price': '$2,500', 'year': '1998', 'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-1998-chevy-pickup/7786804053.html', 'brand': 'chevy'}, {'title': '2004 chevy blazer', 'price': '$4,000', 'year': '2004', 'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-2004-chevy-blazer/7786802056.html', 'brand': 'chevy'}, {'title': '2007 mercedes benz c280 or 2005 benz e500 4matic $3950', 'price': '$4,950', 'year': '2007', 'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2007-mercedes-benz-c280-or-2005/7786722300.html', 'brand': 'missing'}, {'title': '2005 nissan maxima se', 'price': '$3,500', 'year': '2005', 'link': 'https://charlottesville.craigslist.org/cto/d/dillwyn-2005-nissan-maxima-se/7786586063.html', 'brand': 'missing'}, {'title': '2012 subaru impreza 2.0i premium sedan 4d', 'price': '$7,400', 'year': '2012', 'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2012-subaru-impreza-20i/7786582182.html', 'brand': 'subaru'}, {'title': '2008 chevrolet silverado', 'price': '$6,000', 'year': '2008', 'link': 'https://charlottesville.craigslist.org/cto/d/stuarts-draft-2008-chevrolet-silverado/7786493479.html', 'brand': 'chevrolet'}, {'title': '2012 honda civic lx', 'price': '$5,900', 'year': '2012', 'link': ' ...

# %% [markdown]
# ## 3. Wrangle your data, do some EDA, and make some plots. Try to find some interesting relationships or stories to tell about your data.

# %% [markdown]
# With the data scraped from Craigslist, we can put it in a dataframe and wrangle it. Of course, price and year come in as text, not numbers, and need to be typecast/coerced:

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
df.to_csv('craigslist_cville_cars.csv') # Save data in case of a disaster
df.head()
# Out:
# (100, 6)
#                               title  price    year  \
# 0             2016 nissan altima sl   4800  2016.0
# 1                             buick   4000     NaN
# 2            2006 buick lacrosse cx   2600  2006.0
# 3  2005 ford f-150 2wd- not running   1000  2005.0
# 4               2008 subaru impreza   2000  2008.0
#
#                                                 link    brand   age
# 0  https://charlottesville.craigslist.org/cto/d/p...  missing   9.0
# 1  https://charlottesville.craigslist.org/cto/d/w...    buick   NaN
# 2  https://charlottesville.craigslist.org/cto/d/c...    buick  19.0
# 3  https://charlottesville.craigslist.org/cto/d/c...     ford  20.0
# 4  https://charlottesville.craigslist.org/cto/d/c...   subaru  17.0

# %% [markdown]
# With the data in and wrangled, we can now do EDA:

# %%
# EDA for price and age:
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()
# Out:
# count      100.000000
# mean      8066.240000
# std       7576.456257
# min         10.000000
# 25%       3150.000000
# 50%       5250.000000
# 75%      10225.000000
# max      38000.000000
# Name: price, dtype: float64
# count    80.000000
# mean     20.562500
# std      12.754591
# min       4.000000
# 25%      13.750000
# 50%      18.000000
# 75%      22.250000
# max      67.000000
# Name: age, dtype: float64

# %%
# Price by brand:
df.loc[:,['price','brand']].groupby('brand').describe()
# Out:
#            price                                                          \
#            count          mean           std      min       25%      50%
# brand
# acura        1.0   3500.000000           NaN   3500.0   3500.00   3500.0
# audi         2.0   6432.500000   7399.872465   1200.0   3816.25   6432.5
# bmw          4.0   5850.000000   2248.703330   3000.0   5175.00   5950.0
# buick        3.0   3700.000000    984.885780   2600.0   3300.00   4000.0
# chevrolet    4.0   8750.000000   5866.571969   5000.0   5750.00   6250.0
# chevy        6.0   2551.666667   1778.993161     10.0   1225.00   3250.0
# dodge        5.0   5740.000000   3080.259729   2000.0   3700.00   6000.0
# ford         8.0   7806.250000   5888.999278   1000.0   3000.00   7775.0
# gmc          4.0   5750.000000   2436.527584   3500.0   4025.00   5300.0
# honda       10.0   7164.900000   3914.201790   1000.0   4775.00   7200.0
# jeep         4.0   9000.000000   8256.310718   1500.0   2625.00   7750.0
# kia          2.0   6500.000000   4242.640687   3500.0   5000.00   6500.0
# lexus        1.0  14950.000000           NaN  14950.0  14950.00  14950.0
# missing     27.0   9644.444444   8965.160487   1200.0   2900.00   5500.0
# mitsubishi   1.0   3200.000000           NaN   3200.0   3200.00   3200.0
# subaru       5.0   8140.000000   8021.097182   2000.0   3500.00   5800.0
# tesla        2.0  21450.000000   6434.671709  16900.0  19175.00  21450.0
# toyota       8.0  12431.250000  13941.022137   1500.0   3450.00   5800.0
# volkswagen   1.0   4950.000000           NaN   4950.0   4950.00   4950.0
# volvo        2.0   2050.000000     70.710678   2000.0   2025.00   2050.0
#
#
#                  75%      max
# brand
# acura        3500.00   3500.0
# audi         9048.75  11665.0
# bmw          6625.00   8500.0
# buick        4250.00   4500.0
# chevrolet    9250.00  17500.0
# chevy        4000.00   4000.0
# dodge        7000.00  10000.0
# ford        11050.00  18500.0
# gmc          7025.00   8900.0
# honda        9637.50  13000.0
# jeep        14125.00  19000.0
# kia          8000.00   9500.0
# lexus       14950.00  14950.0
# missing     15000.00  31950.0
# mitsubishi   3200.00   3200.0
# subaru       7400.00  22000.0
# tesla       23725.00  26000.0
# toyota      15887.50  38000.0
# volkswagen   4950.00   4950.0
# volvo        2075.00   2100.0

# %%
# Age by brand:
df.loc[:,['age','brand']].groupby('brand').describe()
# Out:
#              age
#            count       mean        std   min    25%   50%    75%   max
# brand
# acura        1.0  17.000000        NaN  17.0  17.00  17.0  17.00  17.0
# audi         1.0  21.000000        NaN  21.0  21.00  21.0  21.00  21.0
# bmw          2.0  12.500000   2.121320  11.0  11.75  12.5  13.25  14.0
# buick        1.0  19.000000        NaN  19.0  19.00  19.0  19.00  19.0
# chevrolet    4.0  29.500000   8.962886  17.0  26.00  32.5  36.00  36.0
# chevy        5.0  23.400000   6.066300  15.0  21.00  23.0  27.00  31.0
# dodge        1.0  21.000000        NaN  21.0  21.00  21.0  21.00  21.0
# ford         7.0  28.285714  19.006265  13.0  17.50  20.0  31.50  67.0
# gmc          4.0  19.500000   7.325754  10.0  16.00  20.5  24.00  27.0
# honda       10.0  17.000000   7.180220  10.0  11.25  15.5  20.50  33.0
# jeep         3.0  37.333333  22.368132  22.0  24.50  27.0  45.00  63.0
# kia          2.0  12.500000   4.949747   9.0  10.75  12.5  14.25  16.0
# lexus        1.0  15.000000        NaN  15.0  15.00  15.0  15.00  15.0
# missing     20.0  21.550000  16.349714   6.0  14.00  17.5  20.25  62.0
# mitsubishi   1.0  19.000000        NaN  19.0  19.00  19.0  19.00  19.0
# subaru       5.0  14.400000   4.560702   7.0  13.00  17.0  17.00  18.0
# tesla        2.0   8.000000   1.414214   7.0   7.50   8.0   8.50   9.0
# toyota       7.0  14.571429   8.695921   4.0   7.00  17.0  20.00  27.0
# volkswagen   1.0  15.000000        NaN  15.0  15.00  15.0  15.00  15.0
# volvo        2.0  27.000000   8.485281  21.0  24.00  27.0  30.00  33.0

# %%
ax = sns.scatterplot(data=df, x='age', y='price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df['log_price'] = np.log(df['price'])
df['log_age'] = np.log(df['age'])

ax = sns.scatterplot(data=df, x='log_age', y='log_price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['log_price','log_age']].cov())
print(df.loc[:,['log_price','log_age']].corr())
# Out:
#            log_price   log_age
# log_price   1.148815 -0.166038
# log_age    -0.166038  0.311652
#            log_price   log_age
# log_price   1.000000 -0.323202
# log_age    -0.323202  1.000000

# %%
sns.jointplot(data=df, x='log_age', y='log_price',kind='hex')

# %% [markdown]
# ## 4. (Optional) From your search results, crawl to the links and extract more information about every listing in your original dataframe. Wrangle and do some EDA.

# %% [markdown]
# The final thing we want to do is go from scraping a single page to crawling around.
#
# The idea here is that every web page is connected to some other page. By extracting links as we move from page to page, we can create a web crawler that wanders around for us, gathering information of interest.
#
# In this case, we want to use the search results to then visit each individual page for each listing. Since we saved the links to the web pages in the previous scrape, we can now simply for-loop over that column in the dataframe, visiting the page listing for each of the cars in the search results:

# %%
import time # Time delays
import random # Random numbers

links = df['link']
data = []
for link in links: # about 3 minutes
    time.sleep(random.randint(1, 3)) # Random delays
    raw = requests.get(link,headers=header) # Get page
    bsObj = soup(raw.content,'html.parser') # Parse the html
    #
    try:
        year_post = bsObj.find(class_='attr important').find(class_ = 'valu year').get_text()
    except:
        year_post = np.nan
    #
    try:
        condition = bsObj.find(class_='attr condition').find(href=True).get_text()
    except:
        condition = 'missing'
    #
    try:
        cylinders = bsObj.find(class_='attr auto_cylinders').find(class_ = 'valu').get_text()
        cylinders = cylinders.replace('\n','')
    except:
        cylinders = 'missing'
    #
    try:
        drivetrain = bsObj.find(class_='attr auto_drivetrain').find(href=True).get_text()
    except:
        drivetrain = 'missing'
    #
    try:
        fuel = bsObj.find(class_='attr auto_fuel_type').find(href = True).get_text()
    except:
        fuel = 'missing'
    #
    try:
        miles = bsObj.find(class_='attr auto_miles').find(class_ = 'valu').get_text()
    except:
        miles = np.nan
    #
    try:
        color = bsObj.find(class_='attr auto_paint').find(href=True).get_text()
    except:
        color='missing'
    #
    try:
        title = bsObj.find(class_='attr auto_title_status').find(href=True).get_text()
    except:
        title='missing'
    #
    try:
        transmission = bsObj.find(class_='attr auto_transmission').find(href=True).get_text()
    except:
        transmission = 'missing'
    #
    try:
        bodytype = bsObj.find(class_='attr auto_bodytype').find(href=True).get_text()
    except:
        bodytype = 'missing'
    #
    text = bsObj.find(id='postingbody').get_text()
    text = text.replace('\n','')
    text = text.replace('QR Code Link to This Post','')
    record = {'title':title,
              'year_post':year_post,
              'condition':condition,
              'cylinders':cylinders,
              'drivetrain':drivetrain,
              'fuel':fuel,
              'miles':miles,
              'color':color,
              'title':'title',
              'transmission':transmission,
              'bodytype':bodytype,
              'text':text,}
    data.append(record)

# %% [markdown]
# What are the new features here?
#
# First, we don't want to overwhelm the servers, so we put a small delay between each request of a listing, `time.sleep(random.randint(1, 3))`. This waits a random amount of time between 1 and 3 seconds to avoid overwhelming their server.
#
# Second, we use the try/except block. This is a useful control structure in general, but especially for web scraping. Python tries the statements under `try:`, and if it fails, executes the steps under `except:`. This can happen, in this case, with missing data, which crashes the crawler. Instead, we put our missing codes into our dataframe right away.
#
# Third, we used `.find().find().get_text()` to find the data we're looking for. In general, the structure of mark-up langauges like HTML and XML makes it possible to "drill down" into their entries and extract the information of interest. This exploitation of mark-up languages could be the subject of a whole course on procuring data from the web.

# %% [markdown]
# With the data scraped, we can make a new dataframe, combine it with the old one using `pd.concat`, and do some wrangling to clean the data up:

# %%
new_df = pd.DataFrame.from_dict(data)
new_df.head()

df = pd.concat([df,new_df],axis=1) # combine data frames
df.head()

df['miles'] = df['miles'].str.replace(',','')
df['miles'] = pd.to_numeric(df['miles'],errors='coerce')

df['year_post'] = df['year_post'].str.replace(',','')
df['year_post'] = pd.to_numeric(df['year_post'],errors='coerce')
df.to_csv('craiglist_cville_cars_long.csv')

# %% [markdown]
# **MY RESPONSES:**

# %%
# 1. scrape the craiglist site for clothes and accessories
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'}
url = 'https://charlottesville.craigslist.org/search/jwa?purveyor=owner#search=1~gallery~0~66'
raw = requests.get(url,headers=header) # Get page

# %%
# 2. extract data from the search results

from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings

# %%
data = []


for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    location = listings[k].find('div', class_='location')
    if location:
      location_text = location.get_text(strip=True).lower()
    else:
      location_text = "Location not found"

    data.append({'title':title,'price':price,'link':link,'location':location_text})

# %%
print(data)
# Out:
# [{'title': 'assorted watches', 'price': '$1', 'link': 'https://charlottesville.craigslist.org/jwl/d/culpeper-assorted-watches/7785669568.html', 'location': 'culpeper'}, {'title': '> ladies ring - amethyst, diamonds & 10k gold, vintage piece <', 'price': '$0', 'link': 'https://charlottesville.craigslist.org/jwl/d/charlottesville-ladies-ring-amethyst/7779886244.html', 'location': 'charlottesville'}, {'title': 'blue cat’s eye pendant with antiqued, polished and sealed copper chain.', 'price': '$30', 'link': 'https://charlottesville.craigslist.org/jwl/d/orange-blue-cats-eye-pendant-with/7787961053.html', 'location': 'orange'}, {'title': "14k white gold men's wedding band- newly purchased", 'price': '$1,200', 'link': 'https://charlottesville.craigslist.org/jwl/d/culpeper-14k-white-gold-mens-wedding/7784828929.html', 'location': 'culpeper'}, {'title': 'gold glass heart pendant crystal bead necklace 16 - 18" & earrings', 'price': '$15', 'link': 'https://charlottesville.craigslist.org/jwl/d/earlysville-gold-glass-heart-pendant/7787611563.html', 'location': 'earlysville / charlottesville'}, {'title': 'bunch watches', 'price': '$10', 'link': 'https://charlottesville.craigslist.org/jwl/d/troy-bunch-watches/7782301919.html', 'location': 'louisa'}, {'title': 'older jewelry box', 'price': '$10', 'link': 'https://charlottesville.craigslist.org/jwl/d/troy-older-jewelry-box/7782302040.html', 'location': 'louisa'}, {'title': 'musical jewelry box', 'price': '$10', 'link': 'https://charlottesville.craigslist.org/jwl/d/troy-musical-jewelry-box/7783136098.html', 'location': 'louisa'}, {'title': 'jewelry', 'price': '$1', 'link': 'https://charlottesville.craigslist.org/jwl/d/troy-jewelry/7783920615.html', 'location': 'Location not found'}, {'title': '2 pair ear rings', 'price': '$5', 'link': 'https://charlottesville.craigslist.org/jwl/d/troy-pair-ear-rings/7783926088.html', 'location': 'Location not found'}, {'title': 'halloween earring set of 5!', 'price': '$10', 'link': 'https://charlottesville.craigslist.org/jwl/d/bremo-bluff-halloween-earring-set-of/7777979491.html', 'location': 'bremo bluff'}, {'title': 'brand new necklaces & pendents!', 'price': '$15', 'link': 'https://charlottesville.craigslist.org/jwl/d/bremo-bluff-brand-new-necklaces-pendents/7777978375.html', 'location': 'bremo bluff'}, {'title': 'halloween earrings!', 'price': '$5', 'link': 'https://charlottesville.craigslist.org/jwl/d/bremo-bluff-halloween-earrings/7777974966.html', 'location': 'bremo bluff'}, {'title': "vintage men's gucci watch model 4500m", 'price': '$175', 'link': 'https://charlottesville.craigslist.org/jwl/d/charlottesville-vintage-mens-gucci/7784437368.html', 'location': 'charlottesville'}, {'title': 'new sterling silver ring size 9', 'price': '$45', 'link': 'https://charlottesville.craigslist.org/jwl/d/quinque-new-sterling-silver-ring-size/7783761325.html', 'location': 'ruckersville'}, {'title': 'vintage turtle-shaped locket/pillbox on chain', 'price': '$20', 'link': 'https://charlottesville.craigslist.org/jwl/d/charlottesville-vintage-turtle-shaped/7777025625.html', 'location': 'charlottesville'}, {'title': 'new jeweled heart trinket box with hanger', 'price': '$35', 'link': 'https://charlottesville.craigslist.org/jwl/d/earlysville-new-jeweled-heart-trinket/7771706955.html', 'location': 'earlysville'}, {'title': 'ring, tahitian pearl charm, necklace, gold bracalet', 'price': '$1', 'link': 'https://charlottesville.craigslist.org/jwl/d/charlottesville-ring-tahitian-pearl/7777470233.html', 'location': 'charlottesville'}, {'title': 'invicta watch', 'price': '$100', 'link': 'https://charlottesville.craigslist.org/jwl/d/montpelier-station-invicta-watch/7777109415.html', 'location': 'zion crossroads'}, {'title': 'vintage floral ceramic/glass earrings - 6 sets', 'price': '$40', 'link': 'https://charlottesville.craigslist.org/jwl/d/charlottesville-vintage-floral-ceramic/7768569421.html', 'location': 'charlottesville'}, {'title': 'gorgeous damascene brooch and earrings - bl ...

# %%
# 3. wrangle/EDA

df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
print(df.shape)
df.head()
# Out:
# (23, 4)
#                                                title  price  \
# 0                                   assorted watches      1
# 1  > ladies ring - amethyst, diamonds & 10k gold,...      0
# 2  blue cat’s eye pendant with antiqued, polished...     30
# 3  14k white gold men's wedding band- newly purch...   1200
# 4  gold glass heart pendant crystal bead necklace...     15
#
#                                                 link  \
# 0  https://charlottesville.craigslist.org/jwl/d/c...
# 1  https://charlottesville.craigslist.org/jwl/d/c...
# 2  https://charlottesville.craigslist.org/jwl/d/o...
# 3  https://charlottesville.craigslist.org/jwl/d/c...
# 4  https://charlottesville.craigslist.org/jwl/d/e...
#
#                         location
# 0                       culpeper
# 1                charlottesville
# 2                         orange
# 3                       culpeper
# 4  earlysville / charlottesville

# %%
# EDA for price:
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
# Out:
# count      23.000000
# mean       79.913043
# std       247.266678
# min         0.000000
# 25%         7.500000
# 50%        15.000000
# 75%        37.500000
# max      1200.000000
# Name: price, dtype: float64

# %%
# Price by location:
df.loc[:,['price','location']].groupby('location').describe()
# Out:
#                               price                                         \
#                               count        mean         std    min     25%
# location
# Location not found              2.0    3.000000    2.828427    1.0    2.00
# bremo bluff                     3.0   10.000000    5.000000    5.0    7.50
# charlottesville                 6.0   44.333333   65.929255    0.0    5.75
# culpeper                        2.0  600.500000  847.821031    1.0  300.75
# earlysville                     1.0   35.000000         NaN   35.0   35.00
# earlysville / charlottesville   1.0   15.000000         NaN   15.0   15.00
# louisa                          4.0   15.000000   10.000000   10.0   10.00
# madison                         1.0   50.000000         NaN   50.0   50.00
# orange                          1.0   30.000000         NaN   30.0   30.00
# ruckersville                    1.0   45.000000         NaN   45.0   45.00
# zion crossroads                 1.0  100.000000         NaN  100.0  100.00
#
#
#                                  50%     75%     max
# location
# Location not found               3.0    4.00     5.0
# bremo bluff                     10.0   12.50    15.0
# charlottesville                 25.0   37.50   175.0
# culpeper                       600.5  900.25  1200.0
# earlysville                     35.0   35.00    35.0
# earlysville / charlottesville   15.0   15.00    15.0
# louisa                          10.0   15.00    30.0
# madison                         50.0   50.00    50.0
# orange                          30.0   30.00    30.0
# ruckersville                    45.0   45.00    45.0
# zion crossroads                100.0  100.00   100.0

# %%
# subset of major locations
locations = ['charlottesville', 'culpeper', 'bremo bluff', 'louisa', 'orange']

df_filtered = df[df['location'].isin(locations)]

ax = sns.scatterplot(data=df_filtered, x='location', y='price',hue='location')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
